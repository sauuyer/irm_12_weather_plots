# %% [markdown]
# # Wind Direction Focus
#
#
# #### these are the factors as they relate to the ship data coming from the Armstrong
# #### Irminger 10
#
# Wind direction is calulated in the irminger 10 plots as
# wnde, wndn = md2vect(wspd, wdir)
#     calculates the north and east wind vectors from magnitude and direction
#
# ***** SHIP
# wspd = an array of abolute wind speeds (m/s) from the ship.
# wdir = an array of wind directions (degrees) (must be between 0 and 360) from the ship.
# ***** md2vect
# vx = an array the size of wspd with the northerly wind vector
# vy = an array the size of wspd with the easterly wind vector
# *****vect2md
# wnde =
# wndn =
#
# After md2vect determines the vectors, vect2md calculates wind speed and direction from north and east wind vectors.

# %% [markdown]
# # Translating to...
#
#
# #### data outputs from the Armstrong
# absolute wind speeds -> wind vectors ->
#
# #### data outputs from the Revelle
# #### Irminger 12
